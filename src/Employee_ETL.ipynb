# %% [markdown]
# %run is a magic command -->It tells Databricks:
#
# "Execute the Transformations notebook first."

# %%
# %run ./Transformation_module

# %%
data = [
    (1,"sona","IT",50000),
    (2,"shek","HR",40000),
    (3,"anu","IT",50000),
    (3,"anu","IT",50000),
    (4,None,"Sales",60000)
]

columns = ["EmpID","Name","Department","Salary"]

df = spark.createDataFrame(data, columns)

# %%
clean_df = clean_employee(df)

clean_df.show()

# %%
clean_df.write.mode("overwrite").saveAsTable("employee_clean")
