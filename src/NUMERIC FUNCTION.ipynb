# %% [markdown]
# NUMERIC

# %%
data = [
    (101, "Sona", 35000.75, 24),
    (102, "Ram", 42000.20, 27),
    (103, "John", 28500.90, 22),
    (104, "Sara", 52000.10, 30),
    (105, "David", -15000.55, 26)
]

columns = ["Emp_ID", "Name", "Salary", "Age"]

df = spark.createDataFrame(data, columns)

df.display()

# %% [markdown]
# 1. abs()
#
# Returns the absolute value.
#
# Negative becomes positive.

# %%
df.select( "Name",abs("Salary"),).display()
