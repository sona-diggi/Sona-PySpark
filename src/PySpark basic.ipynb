# %% [markdown]
# **READING THE _DATA_**

# %% [markdown]
# Reading csv file

# %% [markdown]
# here when we give header=true then it denoted that the column name is there take that first row as column name

# %%
df =spark.read.csv("/Volumes/workspace/sona/s1/BigMart Sales.csv",header=True, inferSchema=True)
df.printSchema()

# %% [markdown]
# if we give header as false means first row will not be taken as col name and defaultly col name will be created

# %% [markdown]
# CREATING DATA MANUALLY

# %% [markdown]
# here schema is automatically guessed by the spark

# %%
data = [
    (101, "John", "IT", 50000),
    (102, "Alice", "HR", 60000),
    (103, "Bob", "IT", 70000)
]

columns = ["emp_id", "name", "department", "salary"]

dff = spark.createDataFrame(data, columns)

# %% [markdown]
# we can also define schema

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

schema = StructType([
    StructField("emp_id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("department", StringType(), True),
    StructField("salary", IntegerType(), True)
])

dff = spark.createDataFrame(data, schema)

dff.show()

# %%
df.show()

# %%
df.display()

# %% [markdown]
# READING JSON

# %%
dfjson=spark.read.json("/Volumes/workspace/sona/s1/employee.json")

# %%
dfjson.show()

# %% [markdown]
# EXPLICIT SCHEMA IN JSON

# %%
from pyspark.sql.types import *

schema = StructType([
    StructField("emp_id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("department", StringType(), True),
    StructField("salary", IntegerType(), True)
])

dfjson = spark.read.schema(schema).json("employees.json")

# %%
df_nested=spark.read.json("/Volumes/workspace/sona/s1/employee_nested.json")

# %%
df_nested.select("address.city").show()

# %%
df_nested.printSchema()
